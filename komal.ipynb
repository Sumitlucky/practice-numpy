# %%
import numpy as np

data = [10, 20, 30, 40]
s = pd.Series(data)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd

data = {
    "Name": ["Amit", "Rahul", "Neha"],
    "Age": [21, 22, 20],
    "Marks": [85, 90, 88]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  Marks
# 0   Amit   21     85
# 1  Rahul   22     90
# 2   Neha   20     88

# %%
s = pd.Series([10, 20, 30,None])
# print(s.max())
# print(s.mean())
# print(s.min())
# print(s.max())
# print(s.std())
# print(s.median())
# print(s.fillna(87))
# # print(s)

# print(s.isnull())
# print(s[3])

print(s.fillna(45))
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3    45.0
# dtype: float64

# %%
np.random.choice([1, 2, 3, 4, 5], size=3, replace=True)
# Out:
# array([4, 2, 3])

# %%
import numpy as np

otp = np.random.randint(100000, 1000000)
print(otp)
# Out:
# 112705

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot([0, 1, 2, 3, 4, 5], kind="kde")

plt.show()

# %%
from numpy import random

x = random.binomial(n=10, p=0.5, size=10)

print(x)
# Out:
# [4 5 3 3 3 9 6 4 7 4]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.binomial(n=10, p=0.5, size=1000))

plt.show()

# %%
from numpy import random

x = random.uniform(size=(2, 3))

print(x)
# Out:
# [[0.59262615 0.78587413 0.65127327]
#  [0.69716739 0.61136135 0.96875982]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot([0, 1, 2, 3, 4, 5], kind="kde")

plt.show()

# %%
import numpy as np
marks = np.array([60, 70, 80])
print(marks)
for m in marks:
    print(m)
# Out:
# [60 70 80]
# 60
# 70
# 80

# %%
data = np.array([[1, 2, 3],
                 [4, 5, 6]])
print(data)
for row in data:
    print(row)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [1 2 3]
# [4 5 6]

# %%
import numpy as np
arr = np.array([10, 20, 30, 40, 50, 60,45,56,67,23])
parts = np.split(arr, 5)

print(parts)
# Out:
# [array([10, 20]), array([30, 40]), array([50, 60]), array([45, 56]), array([67, 23])]

# %%
data = np.array([[1, 2],
                 [3, 4],
                 [5, 6],
                 [7, 8]])

result = np.array_split(data, 2)
print(result)
# Out:
# [array([[1, 2],
#        [3, 4]]), array([[5, 6],
#        [7, 8]])]

# %%
from numpy import random
import numpy as np
arr = np.array([1, 2, 3, 4, 5])
random.shuffle(arr)
print(arr)
# Out:
# [5 4 3 2 1]

# %%
from numpy import random
import numpy as np
arr = np.array([1, 2, 3, 4, 5])
print(random.permutation(arr))
# Out:
# [5 2 4 1 3]

# %%
import numpy as np
nums = np.array([10, 20, 30, 40, 50])
result = np.random.permutation(nums)
print(result)
# Out:
# [20 30 50 40 10]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

x = np.array([1, 2, 3, 4, 5,6,7,8])
y = np.array([10, 20, 25, 30, 40,78,89,90])

sns.lineplot(x=y, y=x)
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

x = np.array([1, 2, 3, 4, 5,6,7,8])
y = np.array([10, 20, 25, 30, 40,78,89,90])

sns.lineplot(x=x, y=y)
plt.show()
